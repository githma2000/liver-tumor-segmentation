# %% [markdown]
# <a href="https://colab.research.google.com/github/githma2000/liver-tumor-segmentation/blob/main/liver%20tumor%20segmentation%202.5D%203%20slices%20stacked.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
import zipfile
import os

zip_path = '/content/drive/MyDrive/3D data/Preprocessed_3Dircadb_2_5D.zip'

extract_path = '/content/Preprocessed_3Dircadb_2_5D'

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Extraction complete!")
print("Extracted to:", extract_path)
# Out:
# Extraction complete!
# Extracted to: /content/Preprocessed_3Dircadb_2_5D

# %%
import os
import random

# Corrected base_dir (points to the extracted folder)
base_dir = '/content/Preprocessed_3Dircadb_2_5D/Preprocessed_3Dircadb_2_5D'

# List only directories (patients)
all_patients = sorted([
    f for f in os.listdir(base_dir)
    if os.path.isdir(os.path.join(base_dir, f))
])

# Shuffle and split
random.seed(42)
random.shuffle(all_patients)

train_split = int(0.7 * len(all_patients))
val_split = int(0.85 * len(all_patients))

train_patients = all_patients[:train_split]
val_patients = all_patients[train_split:val_split]
test_patients = all_patients[val_split:]

print("Train:", train_patients)
print("Val:", val_patients)
print("Test:", test_patients)
# Out:
# Train: ['3Dircadb1.9', '3Dircadb1.14', '3Dircadb1.4', '3Dircadb1.13', '3Dircadb1.18', '3Dircadb1.3', '3Dircadb1.5', '3Dircadb1.8', '3Dircadb1.15', '3Dircadb1.20', '3Dircadb1.7', '3Dircadb1.19', '3Dircadb1.10', '3Dircadb1.2']
# Val: ['3Dircadb1.11', '3Dircadb1.6', '3Dircadb1.16']
# Test: ['3Dircadb1.17', '3Dircadb1.1', '3Dircadb1.12']

# %%
from tensorflow.keras.utils import Sequence
import numpy as np
import os
import random
import albumentations as A

class IRCADNPYDataset(Sequence):
    def __init__(self, patient_list, base_path, batch_size=8, input_size=(256, 256),
                 shuffle=True, balance_data=True, seed=42):
        self.patient_list = patient_list
        self.base_path = base_path
        self.batch_size = batch_size
        self.input_size = input_size
        self.shuffle = shuffle
        self.balance_data = balance_data
        self.seed = seed

        random.seed(self.seed)
        np.random.seed(self.seed)

        self.augment = A.Compose([
            A.Resize(height=self.input_size[0], width=self.input_size[1]),
            A.CLAHE(clip_limit=2.0, tile_grid_size=(8, 8), p=0.3),
            A.HorizontalFlip(p=0.5),
            A.VerticalFlip(p=0.5),
            A.RandomRotate90(p=0.5),
            A.ShiftScaleRotate(shift_limit=0.05, scale_limit=0.1, rotate_limit=15, p=0.5),
            A.ElasticTransform(alpha=1, sigma=50, p=0.2),  # ✅ Removed alpha_affine
            A.RandomBrightnessContrast(p=0.2),
            A.GaussianBlur(blur_limit=(3, 5), p=0.1),
        ], additional_targets={'mask': 'mask'})

        self.data = self._load_all_files()
        self.on_epoch_end()

    def _load_all_files(self):
        tumor_data = []
        non_tumor_data = []

        for patient in self.patient_list:
            img_dir = os.path.join(self.base_path, patient, 'IMAGES_2.5D')
            mask_dir = os.path.join(self.base_path, patient, 'LABELS')

            img_files = sorted(os.listdir(img_dir))
            mask_files = sorted(os.listdir(mask_dir))

            for img_file, mask_file in zip(img_files, mask_files):
                img_path = os.path.join(img_dir, img_file)
                mask_path = os.path.join(mask_dir, mask_file)

                if os.path.isfile(img_path) and os.path.isfile(mask_path):
                    mask = np.load(mask_path).astype(np.float32)

                    # Check for multi-channel masks and handle them
                    if mask.ndim == 3 and mask.shape[2] > 1:
                        mask = mask[..., 0]  # Take the first channel if multi-channel
                    mask = np.squeeze(mask)  # Remove extra dims (e.g., (H, W, 1) → (H, W))

                    # Just append the original data without any classification
                    tumor_data.append((img_path, mask_path))

        return tumor_data

    def __len__(self):
        return max(1, len(self.data) // self.batch_size)

    def __getitem__(self, idx):
        batch_pairs = self.data[idx * self.batch_size:(idx + 1) * self.batch_size]
        images, masks = [], []

        for img_path, mask_path in batch_pairs:
            img = np.load(img_path).astype(np.float32)
            mask = np.load(mask_path).astype(np.float32)

            if mask.ndim == 2:
                mask = np.expand_dims(mask, axis=-1)
            elif mask.ndim == 3 and mask.shape[2] > 1:
                mask = mask[..., 0:1]

            # Apply augmentations (even though we keep original mask)
            augmented = self.augment(image=img, mask=mask)
            img_aug = augmented['image']
            mask_aug = augmented['mask']

            if img_aug.ndim == 2:
                img_aug = np.expand_dims(img_aug, axis=-1)
            if mask_aug.ndim == 2:
                mask_aug = np.expand_dims(mask_aug, axis=-1)

            images.append(img_aug)
            masks.append(mask_aug)

        if idx == 0:
            print(f"Batch shape: images={np.array(images).shape}, masks={np.array(masks).shape}")

        return np.array(images), np.array(masks)

    def on_epoch_end(self):
        if self.shuffle:
            random.seed(self.seed)
            random.shuffle(self.data)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, UpSampling2D, Input, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.applications import ResNet50

def ASPP(x, filters):
    """Atrous Spatial Pyramid Pooling with Keras-compatible operations"""
    shape = x.shape

    y1 = Conv2D(filters, 1, padding="same", use_bias=False)(x)
    y1 = BatchNormalization()(y1)
    y1 = Activation("relu")(y1)

    y2 = Conv2D(filters, 3, padding="same", dilation_rate=6, use_bias=False)(x)
    y2 = BatchNormalization()(y2)
    y2 = Activation("relu")(y2)

    y3 = Conv2D(filters, 3, padding="same", dilation_rate=12, use_bias=False)(x)
    y3 = BatchNormalization()(y3)
    y3 = Activation("relu")(y3)

    y4 = Conv2D(filters, 3, padding="same", dilation_rate=18, use_bias=False)(x)
    y4 = BatchNormalization()(y4)
    y4 = Activation("relu")(y4)

    # Use GlobalAveragePooling2D and reshape for broadcast
    y5 = tf.keras.layers.GlobalAveragePooling2D()(x)
    y5 = tf.keras.layers.Reshape((1, 1, shape[-1]))(y5)
    y5 = Conv2D(filters, 1, padding="same", use_bias=False)(y5)
    y5 = BatchNormalization()(y5)
    y5 = Activation("relu")(y5)
    y5 = UpSampling2D(size=(shape[1], shape[2]), interpolation="bilinear")(y5)

    y = concatenate([y1, y2, y3, y4, y5])
    y = Conv2D(filters, 1, padding="same", use_bias=False)(y)
    y = BatchNormalization()(y)
    y = Activation("relu")(y)

    return y


def DeeplabV3Plus(input_shape=(256, 256, 3), num_classes=1):  # <-- UPDATED
    """Custom DeepLabV3+ model with ResNet50 backbone"""
    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=input_shape)

    # Use features from different levels of the encoder
    image_features = base_model.get_layer("conv4_block6_2_relu").output
    x = ASPP(image_features, 256)

    x = UpSampling2D(size=(4, 4), interpolation="bilinear")(x)

    low_level_feat = base_model.get_layer("conv2_block3_2_relu").output
    low_level_feat = Conv2D(48, 1, padding="same", use_bias=False)(low_level_feat)
    low_level_feat = BatchNormalization()(low_level_feat)
    low_level_feat = Activation("relu")(low_level_feat)

    x = concatenate([x, low_level_feat])
    x = Conv2D(256, 3, padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(256, 3, padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = UpSampling2D(size=(4, 4), interpolation="bilinear")(x)
    x = Conv2D(num_classes, 1, padding="same", activation="sigmoid")(x)

    model = Model(inputs=base_model.input, outputs=x)
    return model

# %%
import tensorflow as tf

def dice_loss(y_true, y_pred):
    y_true = tf.reshape(y_true, [-1])
    y_pred = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true * y_pred)
    return 1 - (2. * intersection + 1) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + 1)


def iou_metric(y_true, y_pred):
    y_true = tf.reshape(y_true, [-1])
    y_pred = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
    return (intersection + 1) / (union + 1)

model = DeeplabV3Plus(input_shape=(256,256, 3), num_classes=1)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss=dice_loss,
    metrics=[iou_metric]
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
train_dataset = IRCADNPYDataset(
    train_patients,
    base_dir,
    batch_size=8,
    input_size=(256, 256),
    shuffle=True,
    balance_data=True
)

val_dataset = IRCADNPYDataset(
    val_patients,
    base_dir,
    batch_size=8,
    input_size=(256, 256),
    shuffle=False,
    balance_data=False
)

test_dataset = IRCADNPYDataset(
    test_patients,
    base_dir,
    batch_size=8,
    input_size=(256, 256),
    shuffle=False,
    balance_data=False
)
# Out:
# /usr/local/lib/python3.11/dist-packages/albumentations/core/validation.py:111: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
import tensorflow as tf
from tensorflow.keras.optimizers import Adam


early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=7,
    restore_best_weights=True,
    mode='min',
    verbose=1
)


checkpoint = tf.keras.callbacks.ModelCheckpoint(
    '/content/drive/MyDrive/best_deeplab_model.keras',
    monitor='val_loss',
    save_best_only=True,
    mode='min',
    verbose=1
)


lr_schedule = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    verbose=1,
    mode='min',
    min_lr=1e-6
)


history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=50,
    batch_size=16,
    callbacks=[early_stop, checkpoint, lr_schedule]
)
# Out:
# Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
# Epoch 1/50
# 127/233 ━━━━━━━━━━━━━━━━━━━━ 25s 244ms/step - iou_metric: 0.7553 - loss: 0.1401Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - iou_metric: 0.7772 - loss: 0.1263Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
# Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
#
# Epoch 1: val_loss improved from inf to 0.17003, saving model to /content/drive/MyDrive/best_deeplab_model.keras
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 73s 313ms/step - iou_metric: 0.7773 - loss: 0.1262 - val_iou_metric: 0.7098 - val_loss: 0.1700 - learning_rate: 1.0000e-05
# Epoch 2/50
# 127/233 ━━━━━━━━━━━━━━━━━━━━ 25s 241ms/step - iou_metric: 0.8520 - loss: 0.0801Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - iou_metric: 0.8569 - loss: 0.0773Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
#
# Epoch 2: val_loss did not improve from 0.17003
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 65s 280ms/step - iou_metric: 0.8570 - loss: 0.0773 - val_iou_metric: 0.7093 - val_loss: 0.1724 - learning_rate: 1.0000e-05
# Epoch 3/50
# 127/233 ━━━━━━━━━━━━━━━━━━━━ 25s 241ms/step - iou_metric: 0.8825 - loss: 0.0626Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - iou_metric: 0.8828 - loss: 0.0625Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
#
# Epoch 3: val_loss improved from 0.17003 to 0.10180, saving model to /content/drive/MyDrive/best_deeplab_model.keras
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 68s 293ms/step - iou_metric: 0.8828 - loss: 0.0625 - val_iou_metric: 0.8193 - val_loss: 0.1018 - learning_rate: 1.0000e-05
# Epoch 4/50
# 127/233 ━━━━━━━━━━━━━━━━━━━━ 25s 242ms/step - iou_metric: 0.8922 - loss: 0.0572Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - iou_metric: 0.8929 - loss: 0.0568Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
#
# Epoch 4: val_loss improved from 0.10180 to 0.06154, saving model to /content/drive/MyDrive/best_deeplab_model.keras
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 67s 285ms/step - iou_metric: 0.8929 - loss: 0.0568 - val_iou_metric: 0.8851 - val_loss: 0.0615 - learning_rate: 1.0000e-05
# Epoch 5/50
# 127/233 ━━━━━━━━━━━━━━━━━━━━ 25s 241ms/step - iou_metric: 0.8974 - loss: 0.0543Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - iou_metric: 0.8983 - loss: 0.0538Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
#
# Epoch 5: val_loss did not improve from 0.06154
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 82s 286ms/step - iou_metric: 0.8983 - loss: 0.0538 - val_iou_metric: 0.8859 - val_loss: 0.0616 - learning_rate: 1.0000e-05
# Epoch 6/50
# 127/233 ━━━━━━━━━━━━━━━━━━━━ 25s 240ms/step - iou_metric: 0.9027 - loss: 0.0514Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - iou_metric: 0.9033 - loss: 0.0511Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
#
# Epoch 6: val_loss improved from 0.06154 to 0.06015, saving model to /content/drive/MyDrive/best_deeplab_model.keras
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 66s 283ms/step - iou_metric: 0.9033 - loss: 0.0511 - val_iou_metric: 0.8883 - val_loss: 0.0601 - learning_rate: 1.0000e-05
# Epoch 7/50
# 127/233 ━━━━━━━━━━━━━━━━━━━━ 25s 242ms/step - iou_metric: 0.9029 - loss: 0.0513Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - iou_metric: 0.9049 - loss: 0.0502Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
#
# Epoch 7: val_loss improved from 0.06015 to 0.05728, saving model to /content/drive/MyDrive/best_deeplab_model.keras
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 67s 285ms/step - iou_metric: 0.9049 - loss: 0.0502 - val_iou_metric: 0.8931 - val_loss: 0.0573 - learning_rate: 1.0000e-05
# Epoch 8/50
# 128/233 ━━━━━━━━━━━━━━━━━━━━ 25s 242ms/step - iou_metric: 0.9076 - loss: 0.0487Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - iou_metric: 0.9080 - loss: 0.0485Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
#
# Epoch 8: val_loss improved from 0.05728 to 0.04985, saving model to /content/drive/MyDrive/best_deeplab_model.keras
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 66s 284ms/step - iou_metric: 0.9080 - loss: 0.0484 - val_iou_metric: 0.9058 - val_loss: 0.0499 - learning_rate: 1.0000e-05
# Epoch 9/50
# 127/233 ━━━━━━━━━━━━━━━━━━━━ 25s 242ms/step - iou_metric: 0.9183 - loss: 0.0428Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - iou_metric: 0.9169 - loss: 0.0435Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
#
# Epoch 9: val_loss did not improve from 0.04985
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 64s 276ms/step - iou_metric: 0.9169 - loss: 0.0435 - val_iou_metric: 0.9027 - val_loss: 0.0519 - learning_rate: 1.0000e-05
# Epoch 10/50
# 127/233 ━━━━━━━━━━━━━━━━━━━━ 25s 240ms/step - iou_metric: 0.9105 - loss: 0.0471Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - iou_metric: 0.9129 - loss: 0.0458Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
#
# Epoch 10: val_loss did not improve from 0.04985
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 66s 284ms/step - iou_metric: 0.9129 - loss: 0.0458 - val_iou_metric: 0.8958 - val_loss: 0.0559 - learning_rate: 1.0000e-05
# Epoch 11/50
# 127/233 ━━━━━━━━━━━━━━━━━━━━ 25s 241ms/step - iou_metric: 0.9188 - loss: 0.0425Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - iou_metric: 0.9181 - loss: 0.0429Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
#
# Epoch 11: val_loss did not improve from 0.04985
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 63s 268ms/step - iou_metric: 0.9181 - loss: 0.0429 - val_iou_metric: 0.9002 - val_loss: 0.0533 - learning_rate: 1.0000e-05
# Epoch 12/50
# 128/233 ━━━━━━━━━━━━━━━━━━━━ 25s 241ms/step - iou_metric: 0.9210 - loss: 0.0413Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - iou_metric: 0.9225 - loss: 0.0405Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
#
# Epoch 12: val_loss improved from 0.04985 to 0.04892, saving model to /content/drive/MyDrive/best_deeplab_model.keras
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 67s 288ms/step - iou_metric: 0.9225 - loss: 0.0405 - val_iou_metric: 0.9078 - val_loss: 0.0489 - learning_rate: 5.0000e-06
# Epoch 13/50
# 127/233 ━━━━━━━━━━━━━━━━━━━━ 25s 243ms/step - iou_metric: 0.9225 - loss: 0.0405Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - iou_metric: 0.9229 - loss: 0.0403Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
#
# Epoch 13: val_loss did not improve from 0.04892
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 63s 271ms/step - iou_metric: 0.9229 - loss: 0.0403 - val_iou_metric: 0.9004 - val_loss: 0.0533 - learning_rate: 5.0000e-06
# Epoch 14/50
# 127/233 ━━━━━━━━━━━━━━━━━━━━ 25s 240ms/step - iou_metric: 0.9236 - loss: 0.0399Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - iou_metric: 0.9232 - loss: 0.0401Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
#
# Epoch 14: val_loss did not improve from 0.04892
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 66s 282ms/step - iou_metric: 0.9232 - loss: 0.0401 - val_iou_metric: 0.9021 - val_loss: 0.0521 - learning_rate: 5.0000e-06
# Epoch 15/50
# 128/233 ━━━━━━━━━━━━━━━━━━━━ 25s 240ms/step - iou_metric: 0.9267 - loss: 0.0383Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - iou_metric: 0.9263 - loss: 0.0385Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
#
# Epoch 15: val_loss improved from 0.04892 to 0.04817, saving model to /content/drive/MyDrive/best_deeplab_model.keras
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 65s 279ms/step - iou_metric: 0.9263 - loss: 0.0385 - val_iou_metric: 0.9091 - val_loss: 0.0482 - learning_rate: 5.0000e-06
# Epoch 16/50
# 127/233 ━━━━━━━━━━━━━━━━━━━━ 25s 242ms/step - iou_metric: 0.9275 - loss: 0.0378Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - iou_metric: 0.9262 - loss: 0.0385Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
#
# Epoch 16: val_loss did not improve from 0.04817
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 66s 282ms/step - iou_metric: 0.9262 - loss: 0.0385 - val_iou_metric: 0.9086 - val_loss: 0.0486 - learning_rate: 5.0000e-06
# Epoch 17/50
# 127/233 ━━━━━━━━━━━━━━━━━━━━ 25s 241ms/step - iou_metric: 0.9261 - loss: 0.0385Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - iou_metric: 0.9255 - loss: 0.0389Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
#
# Epoch 17: val_loss did not improve from 0.04817
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 63s 269ms/step - iou_metric: 0.9255 - loss: 0.0389 - val_iou_metric: 0.9073 - val_loss: 0.0492 - learning_rate: 5.0000e-06
# Epoch 18/50
# 127/233 ━━━━━━━━━━━━━━━━━━━━ 25s 240ms/step - iou_metric: 0.9243 - loss: 0.0395Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - iou_metric: 0.9253 - loss: 0.0390Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
#
# Epoch 18: val_loss did not improve from 0.04817
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 65s 281ms/step - iou_metric: 0.9253 - loss: 0.0390 - val_iou_metric: 0.9080 - val_loss: 0.0489 - learning_rate: 5.0000e-06
# Epoch 19/50
# 127/233 ━━━━━━━━━━━━━━━━━━━━ 25s 240ms/step - iou_metric: 0.9297 - loss: 0.0366Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - iou_metric: 0.9289 - loss: 0.0370Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
#
# Epoch 19: val_loss did not improve from 0.04817
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 63s 270ms/step - iou_metric: 0.9289 - loss: 0.0370 - val_iou_metric: 0.9043 - val_loss: 0.0510 - learning_rate: 2.5000e-06
# Epoch 20/50
# 128/233 ━━━━━━━━━━━━━━━━━━━━ 25s 240ms/step - iou_metric: 0.9274 - loss: 0.0378Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - iou_metric: 0.9271 - loss: 0.0380Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
#
# Epoch 20: val_loss did not improve from 0.04817
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 66s 282ms/step - iou_metric: 0.9271 - loss: 0.0380 - val_iou_metric: 0.9055 - val_loss: 0.0501 - learning_rate: 2.5000e-06
# Epoch 21/50
# 128/233 ━━━━━━━━━━━━━━━━━━━━ 25s 241ms/step - iou_metric: 0.9278 - loss: 0.0376Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - iou_metric: 0.9279 - loss: 0.0376Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
#
# Epoch 21: val_loss improved from 0.04817 to 0.04308, saving model to /content/drive/MyDrive/best_deeplab_model.keras
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 81s 279ms/step - iou_metric: 0.9279 - loss: 0.0376 - val_iou_metric: 0.9182 - val_loss: 0.0431 - learning_rate: 2.5000e-06
# Epoch 22/50
# 127/233 ━━━━━━━━━━━━━━━━━━━━ 25s 240ms/step - iou_metric: 0.9260 - loss: 0.0386Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - iou_metric: 0.9265 - loss: 0.0384Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
#
# Epoch 22: val_loss did not improve from 0.04308
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 83s 285ms/step - iou_metric: 0.9265 - loss: 0.0384 - val_iou_metric: 0.9148 - val_loss: 0.0451 - learning_rate: 2.5000e-06
# Epoch 23/50
# 127/233 ━━━━━━━━━━━━━━━━━━━━ 25s 240ms/step - iou_metric: 0.9306 - loss: 0.0361Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - iou_metric: 0.9290 - loss: 0.0369Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
#
# Epoch 23: val_loss improved from 0.04308 to 0.04241, saving model to /content/drive/MyDrive/best_deeplab_model.keras
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 81s 284ms/step - iou_metric: 0.9290 - loss: 0.0369 - val_iou_metric: 0.9195 - val_loss: 0.0424 - learning_rate: 2.5000e-06
# Epoch 24/50
# 127/233 ━━━━━━━━━━━━━━━━━━━━ 25s 241ms/step - iou_metric: 0.9282 - loss: 0.0374Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - iou_metric: 0.9285 - loss: 0.0372Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
#
# Epoch 24: val_loss did not improve from 0.04241
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 66s 283ms/step - iou_metric: 0.9285 - loss: 0.0372 - val_iou_metric: 0.9110 - val_loss: 0.0471 - learning_rate: 2.5000e-06
# Epoch 25/50
# 127/233 ━━━━━━━━━━━━━━━━━━━━ 25s 240ms/step - iou_metric: 0.9305 - loss: 0.0362Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - iou_metric: 0.9309 - loss: 0.0360Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
#
# Epoch 25: val_loss did not improve from 0.04241
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 63s 271ms/step - iou_metric: 0.9309 - loss: 0.0360 - val_iou_metric: 0.9114 - val_loss: 0.0471 - learning_rate: 2.5000e-06
# Epoch 26/50
# 127/233 ━━━━━━━━━━━━━━━━━━━━ 25s 241ms/step - iou_metric: 0.9325 - loss: 0.0350Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - iou_metric: 0.9322 - loss: 0.0352Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
#
# Epoch 26: val_loss did not improve from 0.04241
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 66s 281ms/step - iou_metric: 0.9322 - loss: 0.0352 - val_iou_metric: 0.9129 - val_loss: 0.0461 - learning_rate: 2.5000e-06
# Epoch 27/50
# 127/233 ━━━━━━━━━━━━━━━━━━━━ 25s 242ms/step - iou_metric: 0.9364 - loss: 0.0330Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - iou_metric: 0.9355 - loss: 0.0334Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
#
# Epoch 27: val_loss did not improve from 0.04241
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 63s 271ms/step - iou_metric: 0.9355 - loss: 0.0335 - val_iou_metric: 0.9092 - val_loss: 0.0482 - learning_rate: 1.2500e-06
# Epoch 28/50
# 127/233 ━━━━━━━━━━━━━━━━━━━━ 25s 241ms/step - iou_metric: 0.9294 - loss: 0.0367Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - iou_metric: 0.9310 - loss: 0.0359Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
#
# Epoch 28: val_loss did not improve from 0.04241
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 66s 284ms/step - iou_metric: 0.9310 - loss: 0.0359 - val_iou_metric: 0.9053 - val_loss: 0.0503 - learning_rate: 1.2500e-06
# Epoch 29/50
# 128/233 ━━━━━━━━━━━━━━━━━━━━ 25s 240ms/step - iou_metric: 0.9307 - loss: 0.0361Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - iou_metric: 0.9318 - loss: 0.0355Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
#
# Epoch 29: val_loss did not improve from 0.04241
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1e-06.
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 63s 271ms/step - iou_metric: 0.9318 - loss: 0.0355 - val_iou_metric: 0.9178 - val_loss: 0.0434 - learning_rate: 1.2500e-06
# Epoch 30/50
# 127/233 ━━━━━━━━━━━━━━━━━━━━ 25s 240ms/step - iou_metric: 0.9311 - loss: 0.0358Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - iou_metric: 0.9322 - loss: 0.0352Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
#
# Epoch 30: val_loss did not improve from 0.04241
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 66s 281ms/step - iou_metric: 0.9322 - loss: 0.0352 - val_iou_metric: 0.9159 - val_loss: 0.0445 - learning_rate: 1.0000e-06
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 23.

# %%
import numpy as np
import cv2
from scipy.ndimage import binary_fill_holes, label
from skimage.morphology import remove_small_objects, remove_small_holes, binary_closing

def postprocess_mask(mask, threshold=0.5, min_size=100):

    binary = (mask > threshold).astype(np.uint8)


    binary = binary_fill_holes(binary).astype(np.uint8)


    binary = remove_small_objects(binary.astype(bool), min_size=min_size).astype(np.uint8)


    binary = binary_closing(binary, selem=np.ones((3, 3))).astype(np.uint8)

    return binary

# %%
import matplotlib.pyplot as plt

# Access training history
train_loss = history.history['loss']
val_loss = history.history.get('val_loss')  # Use .get() in case you trained without val
train_iou = history.history.get('iou_metric')
val_iou = history.history.get('val_iou_metric')

epochs = range(1, len(train_loss) + 1)

# Plot Loss
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, label='Train Loss')
if val_loss:
    plt.plot(epochs, val_loss, label='Val Loss')
plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

# Plot IoU
plt.subplot(1, 2, 2)
if train_iou:
    plt.plot(epochs, train_iou, label='Train IoU')
if val_iou:
    plt.plot(epochs, val_iou, label='Val IoU')
plt.title('IoU vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('IoU')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.models import load_model

model = load_model('/content/drive/MyDrive/best_deeplab_model.keras', compile=False)

# %%
val_generator = IRCADNPYDataset(
    patient_list=val_patients,
    base_path=base_dir,
    batch_size=1,
    input_size=(256, 256),
    shuffle=False,
    balance_data=False
)

test_generator = IRCADNPYDataset(
    patient_list=test_patients,
    base_path=base_dir,
    batch_size=1,
    input_size=(256, 256),
    shuffle=False,
    balance_data=False
)

# %%
def predict_and_postprocess(generator):
    images, masks = [], []

    for i in range(len(generator)):
        img, mask = generator[i]
        pred = model.predict(img)[0]  # since batch_size=1
        pred_pp = postprocess_mask(pred)
        images.append(img[0])     # original image
        masks.append((mask[0], pred_pp))  # true vs predicted

    return images, masks

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
import numpy as np

def visualize_liver_predictions(images, true_masks, pred_masks, n_samples=3, figsize=(15, 10), title='Prediction Visualization'):
    """
    Visualize real liver CT images with ground truth and predicted segmentation masks.

    Parameters:
    - images: List or array of image arrays (2D or 3D per slice)
    - true_masks: List or array of ground truth masks
    - pred_masks: List or array of predicted masks (post-processed)
    - n_samples: Number of samples to visualize
    - figsize: Size of the figure
    - title: Title of the figure
    """
    n_samples = min(n_samples, len(images))

    colors = {
        'gt': [0, 1, 0, 0.5],    # Green
        'pred': [1, 0, 0, 0.5],  # Red
        'tp': [1, 1, 0, 0.7],    # Yellow
    }

    fig, axes = plt.subplots(3, n_samples, figsize=figsize, dpi=300)
    if n_samples == 1:
        axes = np.expand_dims(axes, axis=1)

    for i in range(n_samples):
        img = np.squeeze(images[i])
        gt = np.squeeze(true_masks[i])
        pred = np.squeeze(pred_masks[i])

        # Normalize image
        img = (img - img.min()) / (img.max() - img.min() + 1e-8)

        tp = (gt > 0.5) & (pred > 0.5)
        fp = (gt <= 0.5) & (pred > 0.5)
        fn = (gt > 0.5) & (pred <= 0.5)

        # --- Original CT ---
        axes[0, i].imshow(img, cmap='gray')
        axes[0, i].set_title(f"Image {i+1}")
        axes[0, i].axis('off')

        # --- Ground Truth ---
        axes[1, i].imshow(img, cmap='gray')
        gt_overlay = np.zeros((*gt.shape, 4))
        gt_overlay[gt > 0.5] = colors['gt']
        axes[1, i].imshow(gt_overlay)
        axes[1, i].set_title("Ground Truth")
        axes[1, i].axis('off')

        # --- Prediction Overlay ---
        axes[2, i].imshow(img, cmap='gray')
        overlay = np.zeros((*gt.shape, 4))
        overlay[tp] = colors['tp']
        overlay[fp] = colors['pred']
        overlay[fn] = colors['gt']
        axes[2, i].imshow(overlay)
        axes[2, i].set_title("Prediction Overlay")
        axes[2, i].axis('off')

    # Add legend
    legend_elements = [
        Patch(facecolor=colors['gt'], label='False Negative (Missed)', edgecolor='black'),
        Patch(facecolor=colors['pred'], label='False Positive', edgecolor='black'),
        Patch(facecolor=colors['tp'], label='True Positive', edgecolor='black'),
    ]
    fig.legend(handles=legend_elements, loc='lower center', ncol=3, bbox_to_anchor=(0.5, -0.02), fontsize=10)
    plt.suptitle(title, fontsize=14, fontweight='bold', y=0.98)
    plt.tight_layout()
    plt.show()

# %%
results = main()

# Visualize validation set
visualize_liver_predictions(
    results['val_images'],
    results['val_true_masks'],
    results['val_pred_masks'],
    n_samples=3,
    title="Validation Set - Liver Tumor Segmentation"
)

# Optional: Visualize test set
visualize_liver_predictions(
    results['test_images'],
    results['test_true_masks'],
    results['test_pred_masks'],
    n_samples=3,
    title="Test Set - Liver Tumor Segmentation"
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-104-4bf66c72d21b> in <cell line: 0>()
# ----> 1 results = main()
#       2
#       3 # Visualize validation set
#       4 visualize_liver_predictions(
#       5     results['val_images'],
#
# TypeError: main() missing 3 required positional arguments: 'val_generator', 'test_generator', and 'model'

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
import numpy as np

def visualize_liver_predictions(images, true_masks, pred_masks, n_samples=3, figsize=(15, 10), title='Prediction Visualization'):
    """
    Visualize liver CT images with ground truth and predicted segmentation masks.
    """
    n_samples = min(n_samples, len(images))

    colors = {
        'gt': [0, 1, 0, 0.5],    # Green (False Negative)
        'pred': [1, 0, 0, 0.5],  # Red (False Positive)
        'tp': [1, 1, 0, 0.7],    # Yellow (True Positive)
    }

    fig, axes = plt.subplots(3, n_samples, figsize=figsize, dpi=300)
    if n_samples == 1:
        axes = np.expand_dims(axes, axis=1)

    for i in range(n_samples):
        img = np.squeeze(images[i])
        gt = np.squeeze(true_masks[i])
        pred = np.squeeze(pred_masks[i])

        img = (img - img.min()) / (img.max() - img.min() + 1e-8)

        tp = (gt > 0.5) & (pred > 0.5)
        fp = (gt <= 0.5) & (pred > 0.5)
        fn = (gt > 0.5) & (pred <= 0.5)

        # Original CT
        axes[0, i].imshow(img, cmap='gray')
        axes[0, i].set_title(f"Image {i+1}")
        axes[0, i].axis('off')

        # Ground Truth
        axes[1, i].imshow(img, cmap='gray')
        gt_overlay = np.zeros((*gt.shape, 4))
        gt_overlay[gt > 0.5] = colors['gt']
        axes[1, i].imshow(gt_overlay)
        axes[1, i].set_title("Ground Truth")
        axes[1, i].axis('off')

        # Prediction Overlay
        axes[2, i].imshow(img, cmap='gray')
        overlay = np.zeros((*gt.shape, 4))
        overlay[tp] = colors['tp']
        overlay[fp] = colors['pred']
        overlay[fn] = colors['gt']
        axes[2, i].imshow(overlay)
        axes[2, i].set_title("Prediction Overlay")
        axes[2, i].axis('off')

    legend_elements = [
        Patch(facecolor=colors['gt'], label='False Negative (Missed)', edgecolor='black'),
        Patch(facecolor=colors['pred'], label='False Positive', edgecolor='black'),
        Patch(facecolor=colors['tp'], label='True Positive', edgecolor='black'),
    ]
    fig.legend(handles=legend_elements, loc='lower center', ncol=3, bbox_to_anchor=(0.5, -0.02), fontsize=10)
    plt.suptitle(title, fontsize=14, fontweight='bold', y=0.98)
    plt.tight_layout()
    plt.show()


# --- Assuming your main function returns pre-loaded arrays like below ---
def main():
    # Dummy structure (replace this with actual loading or inference)
    return {
        'val_images': np.load("val_images.npy"),          # shape: [N, H, W]
        'val_true_masks': np.load("val_true_masks.npy"),  # shape: [N, H, W]
        'val_pred_masks': np.load("val_pred_masks.npy"),  # shape: [N, H, W]
        'test_images': np.load("test_images.npy"),
        'test_true_masks': np.load("test_true_masks.npy"),
        'test_pred_masks': np.load("test_pred_masks.npy"),
    }

if __name__ == "__main__":
    results = main()

    # Visualize validation set
    visualize_liver_predictions(
        results['val_images'],
        results['val_true_masks'],
        results['val_pred_masks'],
        n_samples=3,
        title="Validation Set - Liver Tumor Segmentation"
    )

    # Visualize test set
    visualize_liver_predictions(
        results['test_images'],
        results['test_true_masks'],
        results['test_pred_masks'],
        n_samples=3,
        title="Test Set - Liver Tumor Segmentation"
    )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-105-ad415a1cba55> in <cell line: 0>()
#      77
#      78 if __name__ == "__main__":
# ---> 79     results = main()
#      80
#      81     # Visualize validation set
#
# <ipython-input-105-ad415a1cba55> in main()
#      68     # Dummy structure (replace this with actual loading or inference)
#      69     return {
# ---> 70         'val_images': np.load("val_images.npy"),          # shape: [N, H, W]
#      71         'val_true_masks': np.load("val_true_masks.npy"),  # shape: [N, H, W]
#      72         'val_pred_masks': np.load("val_pred_masks.npy"),  # shape: [N, H, W]
#
# /usr/local/lib/python3.11/dist-packages/numpy/lib/_npyio_impl.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     453             own_fid = False
#     454         else:
# --> 455             fid = stack.enter_context(open(os.fspath(file), "rb"))
#     456             own_fid = True
#     457
#
# FileNotFoundError: [Errno 2] No such file or directory: 'val_images.npy'

# %%
import numpy as np
import cv2
from scipy.ndimage import distance_transform_edt as distance
from scipy.ndimage import binary_closing, generate_binary_structure
from sklearn.metrics import jaccard_score, f1_score, accuracy_score
import matplotlib.pyplot as plt

# -------- Enhanced Postprocessing --------
def keep_largest_connected_component(mask):
    """
    Keep only the largest connected component in a 2D binary mask.
    """
    num_labels, labels, stats, _ = cv2.connectedComponentsWithStats(mask, connectivity=8)
    if num_labels <= 1:
        return mask
    largest = 1 + np.argmax(stats[1:, cv2.CC_STAT_AREA])
    return (labels == largest).astype(np.uint8)

def smooth_boundaries(mask):
    blurred = cv2.GaussianBlur(mask.astype(np.float32), (5, 5), 0)
    return (blurred > 0.5).astype(np.uint8)

def postprocess_mask(pred_mask, threshold=0.5, use_3d=False):
    """
    Apply post-processing steps:
    - Thresholding
    - Morphology (2D or 3D)
    - Largest component
    - Smoothing
    """
    binary_mask = (pred_mask > threshold).astype(np.uint8)

    if use_3d:
        structure = generate_binary_structure(3, 2)
        binary_mask = binary_closing(binary_mask, structure=structure).astype(np.uint8)
    else:
        processed = np.zeros_like(binary_mask)
        for i in range(binary_mask.shape[0]):
            slice_mask = binary_mask[i]
            kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (3, 3))
            opened = cv2.morphologyEx(slice_mask, cv2.MORPH_OPEN, kernel)
            closed = cv2.morphologyEx(opened, cv2.MORPH_CLOSE, kernel)
            largest = keep_largest_connected_component(closed)
            smoothed = smooth_boundaries(largest)
            processed[i] = smoothed
        binary_mask = processed

    return binary_mask

# --------- Metrics ---------
def dice_coefficient(y_true, y_pred):
    y_true_f = y_true.flatten()
    y_pred_f = y_pred.flatten()
    intersection = np.sum(y_true_f * y_pred_f)
    return (2. * intersection) / (np.sum(y_true_f) + np.sum(y_pred_f) + 1e-7)

def volume_overlap_error(y_true, y_pred):
    intersection = np.sum(y_true * y_pred)
    union = np.sum(y_true) + np.sum(y_pred) - intersection
    return 1 - (intersection / (union + 1e-7))

def relative_volume_difference(y_true, y_pred):
    return (np.sum(y_pred) - np.sum(y_true)) / (np.sum(y_true) + 1e-7)

def assd(y_true, y_pred):
    def surface_distance(a, b):
        a_dist = distance(1 - a)
        b_dist = distance(1 - b)
        sds = []
        for i in np.argwhere(a):
            sds.append(b_dist[tuple(i)])
        for i in np.argwhere(b):
            sds.append(a_dist[tuple(i)])
        return np.array(sds)

    sds = []
    for i in range(y_true.shape[0]):
        s = surface_distance(y_true[i], y_pred[i])
        if s.size > 0:
            sds.append(np.mean(s))
    return np.mean(sds) if sds else 0.0

def rmsd(y_true, y_pred):
    all_dists = []
    for i in range(y_true.shape[0]):
        dists = distance(1 - y_true[i]) * y_pred[i] + distance(1 - y_pred[i]) * y_true[i]
        dists = dists[np.logical_or(y_true[i], y_pred[i])]
        if dists.size > 0:
            all_dists.append(np.sqrt(np.mean(dists**2)))
    return np.mean(all_dists) if all_dists else 0.0

# --------- Evaluation ---------
def evaluate_predictions(y_true_list, y_pred_list):
    y_true_flat = np.concatenate([yt.flatten() for yt in y_true_list])
    y_pred_flat = np.concatenate([yp.flatten() for yp in y_pred_list])

    metrics = {
        'Accuracy': accuracy_score(y_true_flat, y_pred_flat),
        'F1 Score': f1_score(y_true_flat, y_pred_flat),
        'IoU': jaccard_score(y_true_flat, y_pred_flat),
        'Dice Coefficient': np.mean([dice_coefficient(yt, yp) for yt, yp in zip(y_true_list, y_pred_list)]),
        'VOE': np.mean([volume_overlap_error(yt, yp) for yt, yp in zip(y_true_list, y_pred_list)]),
        'RVD': np.mean([relative_volume_difference(yt, yp) for yt, yp in zip(y_true_list, y_pred_list)]),
        'ASSD': np.mean([assd(yt, yp) for yt, yp in zip(y_true_list, y_pred_list)]),
        'RMSD': np.mean([rmsd(yt, yp) for yt, yp in zip(y_true_list, y_pred_list)]),
    }
    return metrics

# --------- Predict & Postprocess ---------
def predict_and_postprocess(generator, model, use_3d=False):
    images, true_masks, pred_masks = [], [], []

    for i in range(len(generator)):
        img_batch, mask_batch = generator[i]
        pred_batch = model.predict(img_batch)

        for j in range(img_batch.shape[0]):
            img = img_batch[j]
            true = mask_batch[j]
            pred = postprocess_mask(pred_batch[j], use_3d=use_3d)
            images.append(img)
            true_masks.append(true)
            pred_masks.append(pred)

    return images, true_masks, pred_masks

# --------- Display Metrics ---------
def display_metrics(val_metrics, test_metrics):
    print("\n" + "=" * 60)
    print(f"{'Metric':<20} {'Validation':<15} {'Test':<15}")
    print("=" * 60)
    for key in val_metrics:
        print(f"{key:<20} {val_metrics[key]:<15.4f} {test_metrics[key]:<15.4f}")
    print("=" * 60)

def main(val_generator, test_generator, model, use_3d_post=False):
    print("Predicting validation data...")
    val_images, val_true, val_pred = predict_and_postprocess(val_generator, model, use_3d=use_3d_post)

    print("Predicting test data...")
    test_images, test_true, test_pred = predict_and_postprocess(test_generator, model, use_3d=use_3d_post)

    print("Evaluating validation metrics...")
    val_metrics = evaluate_predictions(val_true, val_pred)

    print("Evaluating test metrics...")
    test_metrics = evaluate_predictions(test_true, test_pred)

    display_metrics(val_metrics, test_metrics)

    return {
        'val_images': val_images,
        'val_true_masks': val_true,
        'val_pred_masks': val_pred,
        'test_images': test_images,
        'test_true_masks': test_true,
        'test_pred_masks': test_pred,
        'val_metrics': val_metrics,
        'test_metrics': test_metrics
    }


# --------- Replace this block at the bottom of your script ---------

if __name__ == "__main__":
    # Use your defined generators
    val_generator = val_dataset
    test_generator = test_dataset

    # Load your model (replace the path if needed)
    from tensorflow.keras.models import load_model
    model = load_model('/content/drive/MyDrive/best_deeplab_model.keras', compile=False)

    # Run evaluation
    results = main(val_generator, test_generator, model, use_3d_post=False)

    # Optional: Display a few sample results
    import matplotlib.pyplot as plt

def visualize_sample_overlay(image_list, true_mask_list, pred_mask_list, index=0):
    image = normalize_image(image_list[index])
    true_mask = true_mask_list[index].squeeze()
    pred_mask = pred_mask_list[index].squeeze()

    fig, axs = plt.subplots(1, 3, figsize=(12, 4))

    axs[0].imshow(image, cmap='gray')
    axs[0].imshow(true_mask, cmap='Greens', alpha=0.4)
    axs[0].set_title("Image + GT")

    axs[1].imshow(image, cmap='gray')
    axs[1].imshow(pred_mask, cmap='Reds', alpha=0.4)
    axs[1].set_title("Image + Prediction")

    axs[2].imshow(true_mask, cmap='Greens', alpha=0.5)
    axs[2].imshow(pred_mask, cmap='Reds', alpha=0.5)
    axs[2].set_title("GT vs Prediction")

    for ax in axs:
        ax.axis('off')
    plt.tight_layout()
    plt.show()

def normalize_image(img):
    """
    Normalize the image for display (min-max normalization).
    Handles grayscale or single-channel 2D slices.
    """
    img = np.copy(img)
    if img.ndim == 3 and img.shape[-1] == 1:
        img = img.squeeze()
    img = img - np.min(img)
    if np.max(img) != 0:
        img = img / np.max(img)
    return img


    print("\nSample Validation Results:")
    visualize_sample(results['val_images'], results['val_true_masks'], results['val_pred_masks'], index=0)

    print("\nSample Test Results:")
    visualize_sample(results['test_images'], results['test_true_masks'], results['test_pred_masks'], index=0)
# Out:
# Predicting validation data...
# Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# Predicting test data...
# Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# Evaluating validation metrics...
# Evaluating test metrics...
#
# ============================================================
# Metric               Validation      Test
# ============================================================
# Accuracy             0.9493          0.9594
# F1 Score             0.9543          0.9564
# IoU                  0.9125          0.9164
# Dice Coefficient     0.9537          0.9553
# VOE                  0.0837          0.0823
# RVD                  -0.0477         0.0398
# ASSD                 6.1931          6.7391
# RMSD                 7.7297          8.1430
# ============================================================

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def normalize_image(img):
    img = np.copy(img)
    if img.ndim == 3 and img.shape[-1] == 1:
        img = img.squeeze()
    img = img - np.min(img)
    if np.max(img) != 0:
        img = img / np.max(img)
    return img

def overlay_contours(base_img, mask, color=(255, 0, 0)):
    """
    Overlay contour from the binary mask on base_img (grayscale) in the given BGR color.
    """
    contour_img = cv2.cvtColor((base_img * 255).astype(np.uint8), cv2.COLOR_GRAY2BGR)
    contours, _ = cv2.findContours(mask.astype(np.uint8), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cv2.drawContours(contour_img, contours, -1, color, 1)
    return contour_img

def visualize_liver_predictions(images, true_masks, pred_masks, n_samples=3, title="Prediction Samples"):
    indices = np.random.choice(len(images), n_samples, replace=False)

    for idx in indices:
        image = normalize_image(images[idx])
        gt = true_masks[idx].squeeze()
        pred = pred_masks[idx].squeeze()

        overlay_gt = overlay_contours(image, gt, color=(0, 255, 0))      # Green for GT
        overlay_pred = overlay_contours(image, pred, color=(255, 0, 0))  # Red for Prediction

        fig, axs = plt.subplots(1, 3, figsize=(15, 4))
        fig.suptitle(title, fontsize=16)

        axs[0].imshow(image, cmap='gray')
        axs[0].set_title("Original Image")

        axs[1].imshow(overlay_gt)
        axs[1].set_title("Ground Truth Overlay")

        axs[2].imshow(overlay_pred)
        axs[2].set_title("Prediction Overlay")

        for ax in axs:
            ax.axis('off')
        plt.tight_layout()
        plt.show()

# %%
results = main(val_dataset, test_dataset, model, use_3d_post=False)

visualize_liver_predictions(
    results['val_images'],
    results['val_true_masks'],
    results['val_pred_masks'],
    n_samples=3,
    title="Validation Set - Liver Tumor Segmentation"
)

visualize_liver_predictions(
    results['test_images'],
    results['test_true_masks'],
    results['test_pred_masks'],
    n_samples=3,
    title="Test Set - Liver Tumor Segmentation"
)
# Out:
# Predicting validation data...
# Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# Predicting test data...
# Batch shape: images=(8, 256, 256, 3), masks=(8, 256, 256, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# Evaluating validation metrics...
# Evaluating test metrics...
#
# ============================================================
# Metric               Validation      Test
# ============================================================
# Accuracy             0.9520          0.9587
# F1 Score             0.9570          0.9559
# IoU                  0.9175          0.9154
# Dice Coefficient     0.9562          0.9544
# VOE                  0.0795          0.0838
# RVD                  -0.0333         0.0427
# ASSD                 5.5772          6.8781
# RMSD                 7.0250          8.3075
# ============================================================
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-76-0ef0f6040ba1> in <cell line: 0>()
#       1 results = main(val_dataset, test_dataset, model, use_3d_post=False)
#       2
# ----> 3 visualize_liver_predictions(
#       4     results['val_images'],
#       5     results['val_true_masks'],
#
# <ipython-input-75-cc864c96ec43> in visualize_liver_predictions(images, true_masks, pred_masks, n_samples, title)
#      29         pred = pred_masks[idx].squeeze()
#      30
# ---> 31         overlay_gt = overlay_contours(image, gt, color=(0, 255, 0))      # Green for GT
#      32         overlay_pred = overlay_contours(image, pred, color=(255, 0, 0))  # Red for Prediction
#      33
#
# <ipython-input-75-cc864c96ec43> in overlay_contours(base_img, mask, color)
#      16     Overlay contour from the binary mask on base_img (grayscale) in the given BGR color.
#      17     """
# ---> 18     contour_img = cv2.cvtColor((base_img * 255).astype(np.uint8), cv2.COLOR_GRAY2BGR)
#      19     contours, _ = cv2.findContours(mask.astype(np.uint8), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#      20     cv2.drawContours(contour_img, contours, -1, color, 1)
#
# error: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-15:Bad number of channels) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<1>; VDcn = cv::impl::{anonymous}::Set<3, 4>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = cv::impl::<unnamed>::NONE; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 3
